# %%
# 1. Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Real estate.csv")

# %%
X = df[['X3 distance to the nearest MRT station']]
y = df['Y house price of unit area']

# %%
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# %%
model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
X_sorted = X.sort_values(by='X3 distance to the nearest MRT station')
X_sorted_poly = poly.transform(X_sorted)

# %%
y_pred = model.predict(X_sorted_poly)

# %%
plt.scatter(X, y)                # Actual points
plt.plot(X_sorted, y_pred)       # Polynomial curve
plt.xlabel("Distance to MRT Station")
plt.ylabel("House Price per Unit Area")
plt.title("Polynomial Regression (Curved Graph)")
plt.show()
